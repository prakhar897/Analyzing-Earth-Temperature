# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
dataFrame = pd.read_csv('GlobalTemperatures.csv')
dataFrame.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
d1 = dataFrame.ix[:,:2]
d1.head()
# Out:
# c:\users\public\python\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573

# %%
times = pd.DatetimeIndex(d1['dt'])
grouped = d1.groupby([times.year]).mean()

# %%
plt.figure(figsize= (20,10))
plt.plot(grouped['LandAverageTemperature'])
plt.title('Average Land Temperature between 1750 - 2015')
plt.xlabel('Year')
plt.ylabel('Average Land Temperature')
plt.show()

# %%
grouped.head()
# Out:
#       LandAverageTemperature
# dt
# 1750                8.719364
# 1751                7.976143
# 1752                5.779833
# 1753                8.388083
# 1754                8.469333

# %%
d1[times.year == 1752]
# Out:
#             dt  LandAverageTemperature
# 24  1752-01-01                   0.348
# 25  1752-02-01                     NaN
# 26  1752-03-01                   5.806
# 27  1752-04-01                   8.265
# 28  1752-05-01                     NaN
# 29  1752-06-01                     NaN
# 30  1752-07-01                     NaN
# 31  1752-08-01                     NaN
# 32  1752-09-01                     NaN
# 33  1752-10-01                   7.839
# 34  1752-11-01                   7.335
# 35  1752-12-01                   5.086

# %%
d1['LandAverageTemperature']= d1['LandAverageTemperature'].fillna(method='ffill')

# %%
grouped = d1.groupby([times.year]).mean()
plt.figure(figsize=(20,10))
plt.plot(grouped['LandAverageTemperature'])
plt.show()

# %%
from sklearn.linear_model import LinearRegression as LinReg

# %%
x = grouped.index.values.reshape(-1,1)
y = grouped['LandAverageTemperature'].values

# %%
reg = LinReg()
reg.fit(x,y)
y_preds = reg.predict(x)
print("Accuracy" + str(reg.score(x,y)))
# Out:
# Accuracy0.37668322753090727

# %%
plt.figure(figsize = (20,10))
plt.title("Linear Regression")
plt.scatter(x = x, y = y_preds)
plt.scatter(x = x,y =y,c = "b")

# %%
reg.predict(2100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-38fbeb7c30b0> in <module>
# ----> 1 reg.predict(2100)
#
# c:\users\public\python\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# c:\users\public\python\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# c:\users\public\python\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     538                     "Reshape your data either using array.reshape(-1, 1) if "
#     539                     "your data has a single feature or array.reshape(1, -1) "
# --> 540                     "if it contains a single sample.".format(array))
#     541             # If input is 1D raise error
#     542             if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=2100.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
